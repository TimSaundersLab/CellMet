# %%
import os
import time
import numpy as np
import pandas as pd

from skimage import io

import matplotlib.pyplot as plt

from CellSeg.segmentation import Segmentation
from CellSeg.analysis import cell_analysis, edge_analysis, face_analysis
# %load_ext snakeviz

# %%
# path = "/mnt/sda1/For Sophie/Skinner_Jorn_colab/48 hpf 2/"
# seg_filename = "ResliceofC1-Process_230713-MMS-Lyn-GFP_H2A-BFP-wt_03_denoised_cp_masks-sizeFilt.tif_myotome_2.tif-1-edited.tif"
path = "../data/"
seg_filename = "artificial_tissue.tif"
pixel_size = dict(x_size = 0.1071804,
                  y_size = 0.1071804,
                  z_size = 0.5,)

# pixel_size = dict(x_size = 0.183,
#                   y_size = 0.183,
#                   z_size = 0.5,)

# %%
image = io.imread(os.path.join(path, seg_filename))
seg = Segmentation(image, pixel_size, path)

# %%
# %%snakeviz
# start_time = time.time()
# seg.perform_prerequisite()
# Out:
# This folder npz is not empty,
# If you want to save file here, turn overwrite to True
#
# *** Profile stats marshalled to file '/tmp/tmpks145hbc'.
# Embedding SnakeViz in this document...
# <function display at 0x7a6c2a25bba0>
# <iframe id='snakeviz-9fb47f48-0089-11ef-9306-7486e223398f' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-9fb47f48-0089-11ef-9306-7486e223398f").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmpks145hbc")</script>

# %%
# %%snakeviz
# start_time = time.time()
# seg.cell_segmentation()
# # print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#
# *** Profile stats marshalled to file '/tmp/tmp9l1ybktq'.
# Embedding SnakeViz in this document...
# <function display at 0x7a6c2a25bba0>
# <iframe id='snakeviz-a29dc3fe-0089-11ef-9306-7486e223398f' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-a29dc3fe-0089-11ef-9306-7486e223398f").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmp9l1ybktq")</script>

# %%
# %%snakeviz
# from CellSeg.analysis import cell_analysis
# start_time = time.time()
# cell_analysis(seg)
# # print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#
# *** Profile stats marshalled to file '/tmp/tmpr3jq_bs5'.
# Embedding SnakeViz in this document...
# <function display at 0x7a6c2a25bba0>
# <iframe id='snakeviz-ae948e2c-0089-11ef-9306-7486e223398f' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-ae948e2c-0089-11ef-9306-7486e223398f").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmpr3jq_bs5")</script>

# %%
cell_simple_df = pd.read_csv(os.path.join(path,"cell_df.csv"), index_col="Unnamed: 0")

# %%
_=plt.hist(cell_simple_df["area"]/cell_simple_df["volume"])

# %%
cell_simple_df
# Out:
#     id_im    x_center    y_center  z_center  nb_neighbor       volume  \
# 0       1  121.945872   26.571560      74.5            2   797.356964
# 1       2  165.928287   72.621514      74.5            2   580.642670
# 2       3  128.796123   58.452261      74.5            5   992.589374
# 3       4   40.060554  100.467128      74.5            2   462.492312
# 0      20.0  119.000000   26.000000  129.0  90.760451 -112.264296  -1.856927
# 1      20.0  163.500000   73.500000  129.0  89.559086  -38.384747  -0.349276
# 2      20.0  129.000000   59.000000  129.0  89.662889    4.341905   0.025596
# 3      20.0   45.666667  110.000000  129.0  86.225338   32.737712   2.428861
# 4      20.0   81.000000   88.000000  129.0  91.588930 -165.574097  -0.408831
# 5      20.0  103.000000   43.000000  129.0  92.334540  168.870811   0.459498
# 6      20.0   69.000000   65.000000  129.0  90.793420  114.404474   1.748291
# 7      20.0  146.000000   91.625000  129.0  92.008558 -143.806505  -1.469972
# 8      20.0   95.000000   61.000000  129.0  87.958587   45.120623   2.050019
# 9      20.0   68.000000   22.000000  129.0  90.836201  145.007980   0.585362
# 10     20.0  132.000000  154.000000  129.0  91.093279 -178.086421  -0.036532
# 11     20.0  143.000000  128.000000  129.0  89.532766   21.801409   0.186897
# 12     20.0   59.000000   42.000000  129.0  90.357996  157.718335   0.146693
# 13     20.0  176.000000  136.500000  129.0  91.457168 -172.528441  -0.191145
# 14     20.0   41.333333   83.666667  129.0  90.000000    0.000000   0.000000
# 15     20.0   59.000000  135.000000  129.0  89.809446  -84.552343  -1.997308
# 16     20.0  135.000000  112.000000  129.0  89.301094   13.924773   0.173290
# 17     20.0  106.000000  125.000000  129.0  89.903513  -84.072693  -0.929276
# 18     20.0  160.625000  145.250000  129.0  90.497505 -156.868397  -0.212532
# 19     20.0   73.666667  109.333333  129.0  85.620235   34.361533   2.997679
# 20     20.0  108.000000   87.000000  129.0  90.066100 -165.323607  -0.017312
# 21     20.0   79.333333   46.000000  129.0  89.952214  -73.300756  -0.159287
# 22     20.0  169.500000  120.000000  129.0  90.626896 -109.049052  -1.815053
# 23     20.0   76.000000   34.000000  129.0  90.000000    0.000000   0.000000

# %%
cell_simple_df = pd.read_csv("/mnt/sda1/For Sophie/Skinner_Jorn_colab/48 hpf 2/cell_simple_df.csv", index_col="Unnamed: 0")
id_cells = pd.read_csv("/mnt/sda1/For Sophie/Skinner_Jorn_colab/48 hpf 2/nuclei_position_sorted.csv", )
# id_cells = pd.read_csv("/mnt/sda1/For Sophie/Skinner_Jorn_colab/48 hpf 2/id_cells.csv", )

# %%
# remove line with 0 value in id_cell and corresponding nuclei in id_nuclei.csv
id_nuclei_to_remove = id_cells[id_cells["id_cell"]==0][" "].to_numpy()
id_cells.drop(index=id_cells[id_cells["id_cell"]==0].index, inplace=True)
id_cells.sort_values("id_cell", inplace=True)
id_nuclei.drop(index=id_nuclei[id_nuclei["id_nuclei"].isin(id_nuclei_to_remove)].index, inplace=True)
id_nuclei.sort_values("id_nuclei", inplace=True)

# %%
# Keep only segmented cells in one myotome
id_cells = id_cells[id_cells["id_cell"].isin(cell_simple_df['id_im'].to_numpy())]
id_nuclei = id_nuclei[id_nuclei["id_nuclei"].isin(id_cells[" "])]

# %%
# remove cells if they don't have nuclei
cells_without_nuclei = list(set(np.unique(cell_simple_df['id_im']))-set(np.unique(id_cells["id_im"])))
cell_simple_df.drop(index=cell_simple_df[cell_simple_df['id_im'].isin(cells_without_nuclei)].index, inplace=True)
for i in range(len(cell_simple_df)):
    for c in cells_without_nuclei:
        if str(c) in cell_simple_df['ids_neighbor'].iloc[i].split(";"):
            print(str(c) + '\t'+ str(i))
            cell_simple_df.iloc[i,-1] = cell_simple_df.iloc[i]['ids_neighbor'].replace(str(c)+';','')
            cell_simple_df.iloc[i,-2] = cell_simple_df.iloc[i]["nb_neighbor"]-1
# Out:
# 69	0
# 122	1
# 2	3
# 207	4
# 5	5
# 69	5
# 41	5
# 173	5
# 93	5
# 58	9
# 29	9
# 77	10
# 58	10
# 29	10
# 2	11
# 5	14
# 199	14
# 41	14
# 173	14
# 207	14
# 69	15
# 58	16
# 29	16
# 241	17
# 93	17
# 41	18
# 93	18
# 85	18
# 77	19
# 29	19
# 203	21
# 2	23
# 5	25
# 41	25
# 203	26
# 29	27
# 199	29
# 41	29
# 173	29
# 207	29
# 93	29
# 41	30
# 201	30
# 173	30
# 93	30
# 203	31
# 241	32
# 203	34
# 77	34
# 141	34
# 122	37
# 201	37
# 77	37
# 205	37
# 201	38
# 77	38
# 205	38
# 201	39
# 77	42
# 205	42
# 58	42
# 203	44
# 207	50
# 69	53
# 2	58
# 2	59
# 207	59
# 122	60

# %%
# id_cells.to_csv("/mnt/sda1/For Shopie/id_cells_correct.csv")
# id_nuclei.to_csv("/mnt/sda1/For Shopie/id_nuclei_correct.csv")
cell_simple_df.to_csv("/mnt/sda1/For Sophie/Skinner_Jorn_colab/48 hpf 2/cell_simple_df_sorted.csv")

# %%
cell_simple_df
# Out:
#     id_im  nb_neighbor                                    ids_neighbor
# 0       2            5                              239;23;50;102;240;
# 1       5            5                               241;107;62;41;32;
# 2       8            7                        214;210;52;63;69;32;132;
# 3      10            4                                  63;50;122;149;
# 4      21            4                                  50;208;110;63;
# ..    ...          ...                                             ...
# 74    238            1                                            149;
# 75    239            6                            208;2;240;24;50;102;
# 76    240           13  208;107;207;62;239;24;110;2;253;91;102;50;122;
# 77    241            7                          72;93;32;107;5;124;41;
# 78    253            7                      234;91;212;240;122;102;50;
#
# [79 rows x 3 columns]

# %%
np.unique(id_cells["id_im"], return_counts=True)
# Out:
# (array([  8,  10,  21,  23,  24,  32,  36,  39,  43,  45,  49,  50,  52,
#          54,  62,  63,  65,  72,  84,  89,  91,  95,  96, 102, 106, 107,
#         108, 110, 115, 117, 120, 121, 124, 132, 142, 144, 146, 149, 151,
#         152, 156, 157, 164, 166, 167, 171, 179, 182, 183, 195, 208, 210,
#         212, 214, 229, 232, 234, 238, 239, 240, 253]),
#  array([2, 1, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 3, 2, 2, 2, 3, 1, 1, 2, 1, 1,
#         2, 1, 1, 2, 1, 1, 2, 1, 1, 1, 3, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 1,
#         4, 1, 2, 2, 1, 1, 1, 3, 1, 1, 2, 1, 1, 1, 1, 2, 1]))
